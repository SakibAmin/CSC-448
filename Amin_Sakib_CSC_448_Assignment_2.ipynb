# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SakibAmin/CSC-448/blob/main/Amin_Sakib_CSC_448_Assignment_2.ipynb)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.linspace(0, 10, 100)
#y = (-4.9*x**2)+(22*x)+(3)
#y = (-(x-5)**2)+25
y = -2*x+10
x_cord = [0, 10]
y_cord = [0, 0]

data = [[0,10]]
data1 = [[1,8]]
data2= [[2,6]]
data3 = [[3,4]]
data4 = [[4,2]]
data5 = [[5,0]]
data6 = [[6,-2]]
data7 = [[7,-4]]
data8 = [[8,-6]]
data9 = [[9,-8]]
data10 = [[10, -10]]

df = pd.DataFrame(data, columns = ['time', 'velocity'])
df = df.append(pd.DataFrame(data1, columns = ['time', 'velocity']))
df = df.append(pd.DataFrame(data2, columns = ['time', 'velocity']))
df = df.append(pd.DataFrame(data3, columns = ['time', 'velocity']))
df = df.append(pd.DataFrame(data4, columns = ['time', 'velocity']))
df = df.append(pd.DataFrame(data5, columns = ['time', 'velocity']))
df = df.append(pd.DataFrame(data6, columns = ['time', 'velocity']))
df = df.append(pd.DataFrame(data7, columns = ['time', 'velocity']))
df = df.append(pd.DataFrame(data8, columns = ['time', 'velocity']))
df = df.append(pd.DataFrame(data9, columns = ['time', 'velocity']))
df = df.append(pd.DataFrame(data10, columns = ['time', 'velocity']))


display(df)

fig = plt.figure(figsize = (5,5))
#plt.scatter(x_cord, y_cord)
plt.plot(x,y)



plt.show()
# Out:
#    time  velocity
# 0     0        10
# 0     1         8
# 0     2         6
# 0     3         4
# 0     4         2
# 0     5         0
# 0     6        -2
# 0     7        -4
# 0     8        -6
# 0     9        -8
# 0    10       -10

# %% [markdown]
# Explanation:
#
# Above is a code I wrote a couple semesters back for an Assignment I have done before. This was the first time I ever used a jupyter notebook so I decided to share it here. Basically what the code does is we declared several variables that have 2 values within them and those values correlate to time and velocity. We take those variables and append them into a DataFrame table and it creates the table above. After inputting the values into those tables we create a line graph with x =  np.linspace(0, 10, 100)  and y = -2*x+10. If you compare the graph and the table you will see it has the same values.

# %% [markdown]
# ![image.png](attachment:image.png)
